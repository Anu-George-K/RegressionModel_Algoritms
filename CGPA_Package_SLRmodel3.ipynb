# %% [markdown]
# <a href="https://colab.research.google.com/github/Anu-George-K/RegressionModel_Algoritms/blob/main/CGPA_Package_SLRmodel3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/CGPA_Package.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.tail()
# Out:
#      cgpa  package
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33

# %%
df.columns
# Out:
# Index(['cgpa', 'package'], dtype='object')

# %%
df.isna().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
x=df.iloc[:,:-1]
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
x.ndim
# Out:
# 2

# %%
y.ndim
# Out:
# 1

# %%
import matplotlib.pyplot as plt
plt.xlabel("CGPA")
plt.ylabel("Package")
#to display main title
plt.title("CGPA-Package graph")
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)
x_train
# Out:
#      cgpa
# 109  7.77
# 155  6.98
# 113  6.94
# 102  5.13
# 3    7.42
# ..    ...
# 40   9.38
# 108  7.76
# 46   6.07
# 7    6.75
# 142  6.93
#
# [140 rows x 1 columns]

# %%
x_test
# Out:
#      cgpa
# 68   7.56
# 135  6.10
# 84   4.26
# 118  7.40
# 26   8.31
# 190  6.19
# 31   8.10
# 55   8.20
# 70   5.79
# 171  8.01
# 8    6.09
# 105  6.66
# 81   6.10
# 59   7.56
# 136  5.64
# 121  6.50
# 4    6.94
# 41   6.89
# 11   6.61
# 110  8.18
# 87   8.09
# 130  6.68
# 95   6.63
# 92   7.90
# 146  6.07
# 63   9.16
# 18   6.94
# 137  7.14
# 186  7.84
# 159  8.71
# 175  7.04
# 9    8.31
# 169  9.31
# 187  6.26
# 138  7.91
# 124  6.06
# 176  6.29
# 86   7.61
# 33   6.35
# 80   7.63
# 39   7.43
# 161  7.30
# 98   7.69
# 45   7.87
# 53   6.47
# 129  7.29
# 83   8.44
# 183  7.28
# 132  5.84
# 28   5.94
# 117  7.12
# 67   6.51
# 66   5.11
# 122  5.12
# 106  6.13
# 72   7.78
# 160  7.13
# 174  7.32
# 151  6.12
# 167  8.13

# %%
y_train
# Out:
# 109    4.06
# 155    3.09
# 113    2.37
# 102    1.37
# 3      3.67
#        ...
# 40     4.02
# 108    3.54
# 46     2.26
# 7      2.48
# 142    3.04
# Name: package, Length: 140, dtype: float64

# %%
y_test
# Out:
# 68     2.99
# 135    2.60
# 84     1.53
# 118    2.88
# 26     3.42
# 190    2.69
# 31     3.89
# 55     3.39
# 70     2.35
# 171    3.76
# 8      2.31
# 105    2.82
# 81     2.20
# 59     3.31
# 136    2.10
# 121    3.02
# 4      3.57
# 41     2.70
# 11     2.60
# 110    3.76
# 87     3.55
# 130    2.49
# 95     2.79
# 92     4.00
# 146    2.46
# 63     4.25
# 18     2.98
# 137    3.13
# 186    3.47
# 159    4.08
# 175    3.50
# 9      3.51
# 169    4.37
# 187    2.44
# 138    3.89
# 124    2.31
# 176    3.23
# 86     2.77
# 33     2.73
# 80     3.44
# 39     3.33
# 161    3.33
# 98     3.83
# 45     3.58
# 53     2.61
# 129    3.12
# 83     3.49
# 183    2.72
# 132    2.48
# 28     2.24
# 117    2.99
# 67     2.89
# 66     1.63
# 122    2.01
# 106    2.19
# 72     3.62
# 160    2.93
# 174    2.99
# 151    2.76
# 167    3.60
# Name: package, dtype: float64

# %%
#model creation
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([3.32189324, 2.49019684, 1.44203152, 3.23074843, 3.74913453,
#        2.5414658 , 3.62950697, 3.68647248, 2.31360377, 3.57823802,
#        2.48450029, 2.80920368, 2.49019684, 3.32189324, 2.22815551,
#        2.71805887, 2.9687071 , 2.94022434, 2.78072092, 3.67507938,
#        3.62381042, 2.82059678, 2.79211403, 3.51557596, 2.47310719,
#        4.23334134, 2.9687071 , 3.08263811, 3.48139665, 3.97699656,
#        3.0256726 , 3.74913453, 4.3187896 , 2.58134165, 3.52127251,
#        2.46741064, 2.5984313 , 3.35037599, 2.63261061, 3.36176909,
#        3.24783808, 3.17378292, 3.39594839, 3.49848631, 2.70096922,
#        3.16808637, 3.82318969, 3.16238982, 2.34208653, 2.39905203,
#        3.07124501, 2.72375542, 1.92623833, 1.93193488, 2.50728649,
#        3.44721735, 3.07694156, 3.18517602, 2.50158994, 3.64659662])

# %%
y_test
# Out:
# 68     2.99
# 135    2.60
# 84     1.53
# 118    2.88
# 26     3.42
# 190    2.69
# 31     3.89
# 55     3.39
# 70     2.35
# 171    3.76
# 8      2.31
# 105    2.82
# 81     2.20
# 59     3.31
# 136    2.10
# 121    3.02
# 4      3.57
# 41     2.70
# 11     2.60
# 110    3.76
# 87     3.55
# 130    2.49
# 95     2.79
# 92     4.00
# 146    2.46
# 63     4.25
# 18     2.98
# 137    3.13
# 186    3.47
# 159    4.08
# 175    3.50
# 9      3.51
# 169    4.37
# 187    2.44
# 138    3.89
# 124    2.31
# 176    3.23
# 86     2.77
# 33     2.73
# 80     3.44
# 39     3.33
# 161    3.33
# 98     3.83
# 45     3.58
# 53     2.61
# 129    3.12
# 83     3.49
# 183    2.72
# 132    2.48
# 28     2.24
# 117    2.99
# 67     2.89
# 66     1.63
# 122    2.01
# 106    2.19
# 72     3.62
# 160    2.93
# 174    2.99
# 151    2.76
# 167    3.60
# Name: package, dtype: float64

# %%
print(model.predict([[7.25]]))
# Out:
# [3.14530017]
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(model.predict([[6.89]]))
# Out:
# [2.94022434]
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#create a regression line
plt.scatter(x_train,y_train,color='yellow')
plt.plot(x_test,y_pred,color='green')

# %%
print("Slope is",model.coef_)
# Out:
# Slope is [0.56965506]

# %%
print("intercept is",model.intercept_)
# Out:
# intercept is -0.9846990519718841

# %%
df1=pd.DataFrame({'Actual_value':y_test,'Predicted_value':y_pred})
df1
# Out:
#      Actual_value  Predicted_value
# 68           2.99         3.321893
# 135          2.60         2.490197
# 84           1.53         1.442032
# 118          2.88         3.230748
# 26           3.42         3.749135
# 190          2.69         2.541466
# 31           3.89         3.629507
# 55           3.39         3.686472
# 70           2.35         2.313604
# 171          3.76         3.578238
# 8            2.31         2.484500
# 105          2.82         2.809204
# 81           2.20         2.490197
# 59           3.31         3.321893
# 136          2.10         2.228156
# 121          3.02         2.718059
# 4            3.57         2.968707
# 41           2.70         2.940224
# 11           2.60         2.780721
# 110          3.76         3.675079
# 87           3.55         3.623810
# 130          2.49         2.820597
# 95           2.79         2.792114
# 92           4.00         3.515576
# 146          2.46         2.473107
# 63           4.25         4.233341
# ...

# %%
#performance evaluation
#MAE: Mean Absolute Error
#MSE:Mean squared error
#RMSE:Root Mean Squared Error

#MAE-Mean Absolute Error
from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error is",mean_absolute_error(y_test,y_pred))
# Out:
# Mean Absolute Error is 0.1965977056422141

# %%
#Mean absolute percentage error
from sklearn.metrics import mean_absolute_percentage_error
print("Error percentage is",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# Error percentage is 0.06703295328971823

# %%
#Mean Squared Error
from sklearn.metrics import mean_squared_error
print("Mean Squared error is",mean_squared_error(y_test,y_pred))
# Out:
# Mean Squared error is 0.06350008378653735

# %%
#Root Mean Squared Error
root=mean_squared_error(y_test,y_pred)
squ=np.sqrt(root)
squ
# Out:
# 0.2519922296153938

# %%
#r2 score(co-effients of dertermination)

from sklearn.metrics import r2_score
print("r2 score is",r2_score(y_test,y_pred))
# Out:
# r2 score is 0.840123057783385
